# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df
# Out:
#              EIN                                               NAME  \
# 0       10520599                       BLUE KNIGHTS MOTORCYCLE CLUB
# 1       10531628             AMERICAN CHESAPEAKE CLUB CHARITABLE TR
# 2       10547893                 ST CLOUD PROFESSIONAL FIREFIGHTERS
# 3       10553066                     SOUTHSIDE ATHLETIC ASSOCIATION
# 4       10556103           GENETIC RESEARCH INSTITUTE OF THE DESERT
# ...          ...                                                ...
# 34294  996009318              THE LIONS CLUB OF HONOLULU KAMEHAMEHA
# 34295  996010315           INTERNATIONAL ASSOCIATION OF LIONS CLUBS
# 34296  996012607                                PTA HAWAII CONGRESS
# 34297  996015768  AMERICAN FEDERATION OF GOVERNMENT EMPLOYEES LO...
# 34298  996086871                           WATERHOUSE CHARITABLE TR
#
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df.drop(['EIN', 'NAME'], axis=1, inplace=True)

# %%
# Determine the number of unique values in each column.
unique_value_counts = application_df.nunique()
print(unique_value_counts)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts to identify and replace with "Other"

# Get the value counts in the 'column_name'
application_value_counts = application_df['APPLICATION_TYPE'].value_counts()

# Print the value counts to identify values you want to replace
print(application_value_counts)
# Out:
# APPLICATION_TYPE
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_value_counts[application_value_counts < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure replacement was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Look at CLASSIFICATION value counts to identify and replace with "Other"
# Get the value counts in the 'column_name'
classification_value_counts = application_df['CLASSIFICATION'].value_counts()

# Print the value counts to identify values you want to replace
print(classification_value_counts)
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: count, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
gt1_classification_counts = classification_value_counts.loc[classification_value_counts > 1]

print(gt1_classification_counts.head())
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Name: count, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(gt1_classification_counts[gt1_classification_counts < 1000].index)


# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure replacement was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2235
# C3000     1918
# C2100     1883
# C1370        1
# C1236        1
# C2190        1
# C4200        1
# C5200        1
# C1248        1
# C2600        1
# C1580        1
# C6100        1
# C1820        1
# C1900        1
# C2570        1
# C1570        1
# C3700        1
# C2500        1
# C1283        1
# C2380        1
# C1732        1
# C1728        1
# C2170        1
# C4120        1
# C8210        1
# C4500        1
# C1245        1
# C2561        1
# C2150        1
# Name: count, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
numeric_data = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
X = numeric_data.drop(['IS_SUCCESSFUL'], axis=1).values
y = numeric_data['IS_SUCCESSFUL'].values


# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=99)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# %%
# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 6
hidden_nodes_layer2 = 6
hidden_nodes_layer3 = 6


nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='leaky_relu')
)

# Second hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer2, input_dim=number_input_features, activation='leaky_relu')
)

# Third hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer3, input_dim=number_input_features, activation='sigmoid')
)

# Output layer
nn.add(
    tf.keras.layers.Dense(units=1, activation='sigmoid')
)

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 6)                 420
#
#  dense_4 (Dense)             (None, 6)                 42
#
#  dense_5 (Dense)             (None, 6)                 42
#
#  dense_6 (Dense)             (None, 1)                 7
#
# ...
# Total params: 511 (2.00 KB)
# Trainable params: 511 (2.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs = 100
                   )
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.6154 - accuracy: 0.6744
# Epoch 2/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5680 - accuracy: 0.7243
# Epoch 3/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5619 - accuracy: 0.7273
# Epoch 4/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5595 - accuracy: 0.7289
# Epoch 5/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5581 - accuracy: 0.7287
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5574 - accuracy: 0.7294
# Epoch 7/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5567 - accuracy: 0.7289
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5561 - accuracy: 0.7289
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5556 - accuracy: 0.7290
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5524 - accuracy: 0.7308 - 432ms/epoch - 2ms/step
# Loss: 0.5523843169212341, Accuracy: 0.7308454513549805

# %%
# Define the filepath where the weights will be saved

model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath='C:/Users/14407/Documents/Data Analytics_Boot Camp/deep-learning-challenge/AlphabetSoupCharityOptimization_v4.h5', save_freq='epoch', save_best_only=True)


# Export our model to HDF5 file
from google.colab import files

nn.save('C:/Users/14407/Documents/Data Analytics_Boot Camp/deep-learning-challenge/AlphabetSoupCharityOptimization_v4.h5')
files.download('C:/Users/14407/Documents/Data Analytics_Boot Camp/deep-learning-challenge/AlphabetSoupCharityOptimization_v4.h5')
